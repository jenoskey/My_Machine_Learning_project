# %% [markdown]
# #Activations Function

# %% [markdown]
# ##Import library
# - numpy
# - matplotlib.pyplot

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##Create a class called “Activations” has methods (silu, softplus,binary_step, and leaky_relu)

# %%
class Activations():

  def __init__(self,x):
    
    self.x = x

  def silu(self):
    f = []
    f = 1/(1+np.exp(-self.x))
    plt.plot(X,f,'.')
    plt.title('Silu Function')
    plt.show()

  def softplus(self):
    f = []
    f=np.log(1+np.exp(self.x))
    plt.plot(X,f,'.')
    plt.title('Softplus Function')
    plt.show()
    
  def binary_step(self):
    f = []
    for i in self.x:
        if i<=0:
            f.append(0)
        else:
            f.append(1)
    plt.plot(X,f,'.')
    plt.title('Binary Step Function')
    plt.show()
    
  def leaky_relu(self):
    f = []
    for i in self.x:
        if i<=0:
            f.append(0)
        else:
            f.append(i)
    plt.plot(X,f,'.')
    plt.title('Leaky Relu Function')
    plt.show()

# %% [markdown]
# ##Define a variable called X by generating a array of 1000 standard normal random numbers

# %%
X = np.random.randn(1000)

# %% [markdown]
# ##Define object from class Activations

# %%
active_fun = Activations(X)

# %% [markdown]
# ## plot

# %% [markdown]
# ###Silu Function

# %%
active_fun.silu()

# %% [markdown]
# ###Softplus Function

# %%
active_fun.softplus()

# %% [markdown]
# ###Binary Step Function

# %%
active_fun.binary_step()

# %% [markdown]
# ###Leaky Relu Function

# %%
active_fun.leaky_relu()
